# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator
from pathlib import Path
import os
import polars as pl
import numpy as np

from dotenv import load_dotenv

from telegram_quality_control.kde import kde_fit, kde_fit_clustered_bootstrap_CI
from telegram_quality_control.bootstrap import cluster_bootstrap_CI
from telegram_quality_control.visualization import single_col_figure, get_color_cycle

from cmcrameri import cm

figure_style = "print"

plt.style.use('./resources/mpl_styles/default.mplstyle')

load_dotenv(".env")

data_folder = Path(os.environ.get("OUTPUT_FOLDER"))

# %%
data_paths = {
    "telegram": data_folder / "ranked_urls_telegram.parquet",
    "twitter": data_folder / "ranked_urls_twitter.parquet",
}

url_df = {platform: pl.read_parquet(data_paths[platform]) for platform in ["telegram", "twitter"]}
url_df["telegram"]
# Out:
# shape: (17_419_582, 3)
# ┌──────────────────────────┬────────────────┬─────────────┐
# │ domain                   ┆ is_blacklisted ┆ reliability │
# │ ---                      ┆ ---            ┆ ---         │
# │ str                      ┆ bool           ┆ f64         │
# ╞══════════════════════════╪════════════════╪═════════════╡
# │ sbnation.com             ┆ false          ┆ 0.738977    │
# │ abendzeitung-muenchen.de ┆ false          ┆ 0.759919    │
# │ thegatewaypundit.com     ┆ false          ┆ 0.131256    │
# │ washingtonstand.com      ┆ false          ┆ 0.789069    │
# │ newsweek.com             ┆ false          ┆ 0.824813    │
# │ …                        ┆ …              ┆ …           │
# │ blogspot.com             ┆ false          ┆ 0.669402    │
# │ apnews.com               ┆ false          ┆ 0.995746    │
# │ hotair.com               ┆ false          ┆ 0.626332    │
# │ cnn.com                  ┆ false          ┆ 0.67343     │
# │ bestnewshere.com         ┆ false          ┆ 0.250619    │
# └──────────────────────────┴────────────────┴─────────────┘

# %%
num_reliable = len(url_df["telegram"].filter(pl.col("reliability") > pl.lit(0.6)))
total_urls = len(url_df["telegram"].filter(pl.col("reliability").is_not_null()))

print(f"Fraction of unreliable URLs: {1 - num_reliable / total_urls}")
# Out:
# Fraction of unreliable URLs: 0.586379225402768

# %%
kde = {}

for platform in ["telegram", "twitter"]:
    df = url_df[platform]
    kde[platform] = {}
    save_path = data_folder / f"{platform}_url_reliability.npy"

    if save_path.exists():
        data = np.load(save_path)
    else:
        q_points, prob = kde_fit(df["reliability"], bandwidth=0.05)

        lower, upper = kde_fit_clustered_bootstrap_CI(
            df,
            value_col="reliability",
            cluster_col="domain",
            num_bootstrap=1000,
            num_workers=8,
            quantile=0.95,
        )
        data = np.array([q_points, prob, lower, upper])
        np.save(save_path, data)

    kde[platform]["q_points"] = data[0, :]
    kde[platform]["prob"] = data[1, :]
    kde[platform]["lower"] = data[2, :]
    kde[platform]["upper"] = data[3, :]

# %%
fig = single_col_figure(0.8)
ax = fig.add_subplot(111)

colors = {"telegram": get_color_cycle()[0], "twitter": "gray"}
lines = {}
CI_bands = {}

for platform in ["telegram", "twitter"]:
    lines[platform] = ax.plot(
        kde[platform]["q_points"],
        kde[platform]["prob"],
        color=colors[platform],
        label=platform.capitalize(),
    )[0]

    CI_bands[platform] = ax.fill_between(
        kde[platform]["q_points"],
        kde[platform]["lower"],
        kde[platform]["upper"],
        alpha=0.2,
        label="95% CI",
        color=colors[platform],
        edgecolor=None,
    )

ax.set_xlim(0, 1)
ax.set_ylim(bottom=0)

# ax.set_title("Distribution of URLs by reliability")
ax.set_xlabel("Reliability")
ax.set_ylabel("P(reliability)")

ax.xaxis.set_minor_locator(MultipleLocator(0.1))
ax.set_yticks([0, 0.01, 0.02, 0.03])
ax.yaxis.set_minor_locator(MultipleLocator(0.005))

# ax.legend(handles=[lines["telegram"], lines["twitter"], CI_bands["twitter"]], framealpha=0.6)

fig.tight_layout()

fig.savefig(f"./figures/url_reliability.pdf", bbox_inches='tight')
fig.savefig(f"./figures/url_reliability.png", bbox_inches='tight')
