# %%
from eralchemy import render_er

from telegram_quality_control.db import get_conn_string

import matplotlib.pyplot as plt

from cmcrameri import cm

figure_style = "print"

plt.style.use('./resources/mpl_styles/default.mplstyle')

# %%
db_url = get_conn_string()

render_er(db_url, 'figures/er_diagram.png', mode="dot", exclude_tables=["queue"], exclude_columns=["crawl_created_at"])
# render_er(db_url, 'figures/er_diagram.svg', exclude_tables=["queue"], exclude_columns=["crawl_created_at"])
